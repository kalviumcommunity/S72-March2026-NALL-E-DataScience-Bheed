# %% [markdown]
# # Milestone 4.9 — Running, Restarting, and Interrupting Kernels
#
# This notebook demonstrates essential Jupyter kernel management skills required for handling long-running model training sessions.

# %% [markdown]
# ## 1. Kernel Lifecycle
# - **Execution**: Run cells sequentially (Shift+Enter).
# - **Restart**: Use to clear memory and reset state.
# - **Interrupt**: Stop a cell that is taking too long.

# %%
import time

print("Starting a long simulation... (Interrupt the kernel now to test!)")
for i in range(20):
    print(f"Processing city data batch {i+1}...")
    time.sleep(1) # Simulating heavy model training

# %% [markdown]
# ## 2. Reproducibility
# Always use **Restart & Run All** to verify that your notebook can be executed from scratch without manual intervention.
