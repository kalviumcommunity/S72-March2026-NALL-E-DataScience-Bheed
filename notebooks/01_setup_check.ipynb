# %% [markdown]
# # Milestone 4.6 — Verifying Python, Conda, and Jupyter Installation
#
# This notebook verifies that all required libraries for the BheedRadar project are correctly installed and importable.

# %% [markdown]
# ## 1. System Versions
# Checking Python and Conda versions.

# %%
# !python --version
# !conda --version

# %% [markdown]
# ## 2. Library Imports (Core)
# Verifying basic data science libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns

print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print(f"Seaborn version: {sns.__version__}")

# %% [markdown]
# ## 3. Library Imports (Extended)
# Verifying Scikit-Learn and Streamlit.

# %%
import sklearn
import streamlit as st

print(f"Scikit-Learn version: {sklearn.__version__}")
print(f"Streamlit version: {st.__version__}")

# %% [markdown]
# ## 4. Pandas Sanity Test
# Creating a simple DataFrame to ensure everything is working as expected.

# %%
data = {
    'City': ['Jaipur', 'Goa', 'Shimla'],
    'Visitors': [1200, 800, 450],
    'Is_Peak': [True, False, False]
}

df = pd.DataFrame(data)
display(df)
print("\nPandas sanity test passed!")

# %% [markdown]
# ## 5. Environment Status
# Current status: **Ready for Feature 1 (Data Pipeline)**.
